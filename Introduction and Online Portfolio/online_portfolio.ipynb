# %% [markdown]
# # Online Portfolio
# Your company has received a few applications for a computer science position. You are the hiring manager and should review the online portfolios of the applicants. In particular, you should do the following:
# - Write a short review (including 3 strong and 3 weak points) for the online portfolio of each of the following applicants.
#     - [Megan Landau](http://www.meganlandau.com/portfolio-1/).
#     - [Kalyn Nakano](https://kalynnakano.com/).
#     - [Victoria Holland](https://victoria-holland.info/).
#     - [Gautam Krishna](https://www.gautamkrishnar.com/).
#     - [Lakshmi Chandana](https://chandanachaitanya.github.io/).
# - Rank the applicants for the job position based on your reviews.
# - Who will you hire in the end? Why?

# %% [markdown]
# ## 1). Kalyn Nakano -
#
# ### I would hire this candidate in the end after looking at all other portfolios because of the accurateness of the design, structure and because of the professionalism it shows. ###
#
# Strong:
# Looks professional
# Theme suits profession
# Minimal easy to read layout
#
# Weak:
# Could have added a donwloadable resume
# Sidebar at top right does not seem to do anything
# Could have added a contact me form
#
#
# ## 2). Lakshmi Chandana
#
# Strong:
# Nice color and theme option
# Well laid out resume
# Has many projects
#
# Weak:
# Could have used less fancy font
# Could have added resume that can be downloaded
# Could have added contact me form
#
# ## 3). Gautam Krishna
#
# Strong:
# Good design and structure
# Active on github
# Lots of experience
#
# Weak:
# Could have made it a bit toned down
# Could have added resume that can be downloaded
# Could not find many projects
#
# ## 4). Megan Landau
#
# Strong:
# Looks good
# Has good experience
# Has knowledge in arts as well could be a plus
#
# Weak:
# Does not look very professional
# Layout contains lot of pictures which doesnt make it look like portfolio
# Could have added contact me form
#
# ## 5). Victoria Holland
#
# Strong:
# Has lot of work experience
# Has all required things available on website
# Nothing much to add
#
# Weak:
# Looks very outdated
# Does not seem professional
# Could have added downloadable resume
